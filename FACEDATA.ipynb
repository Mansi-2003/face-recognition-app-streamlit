# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA

# %%
# Load the CSV file
df = pd.read_csv(r"C:\Users\mansi\OneDrive\Documents\FaceData.csv")

# %%
# Plot label distribution
plt.figure(figsize=(6, 4))
sns.countplot(x='Label', data=df, palette='Set2')
plt.title('Label Distribution')
plt.xlabel('Label')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\mansi\AppData\Local\Temp\ipykernel_16724\3606730111.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Label', data=df, palette='Set2')

# %%
# Separate features and target label
X = df.drop('Label', axis=1)
y = df['Label']

# %%
#PCA for 2D reduction
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# %%
# Plot 2D PCA 
plt.figure(figsize=(8, 6))
sns.scatterplot(x=X_pca[:, 0], y=X_pca[:, 1], hue=y, palette='Set1', legend='full')
plt.title('PCA Visualization (2D) of Face Data')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(title='Label')
plt.tight_layout()
plt.show()
